# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\Adhil E\\Downloads\\Sample_data.csv")

# %%
df
# Out:
#                  id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7.129301e+09   221900.0       3.0       1.00       1180.0    5650.0
# 1      6.414100e+09   538000.0       3.0       2.25       2570.0    7242.0
# 2      5.631500e+09   180000.0       2.0       1.00        770.0   10000.0
# 3      2.487201e+09   604000.0       4.0       3.00       1960.0    5000.0
# 4      1.954401e+09   510000.0       3.0       2.00       1680.0    8080.0
# 5      7.237550e+09  1230000.0       4.0       4.50       5420.0  101930.0
# 6      1.321400e+09   257500.0       3.0       2.25       1715.0    6819.0
# 7      2.008000e+09   291850.0       3.0       1.50       1060.0    9711.0
# 8      2.414600e+09   229500.0       3.0       1.00       1780.0    7470.0
# 9      3.793500e+09   323000.0       3.0       2.50       1890.0    6560.0
# 10     1.736801e+09   662500.0       3.0       2.50       3560.0    9796.0
# 11     9.212900e+09   468000.0       2.0       1.00       1160.0    6000.0
# 12     1.141015e+08   310000.0       3.0       1.00       1430.0   19901.0
# 13     6.054650e+09   400000.0       3.0       1.75       1370.0    9680.0
# 14     1.175001e+09   530000.0       5.0       2.00       1810.0    4850.0
# 15     9.297300e+09   650000.0       4.0       3.00       2950.0    5000.0
# 16     1.875500e+09   395000.0       3.0       2.00       1890.0   14040.0
# 17     6.865200e+09   485000.0       4.0       1.00       1600.0    4300.0
# 18     1.600040e+07   189000.0       2.0       1.00       1200.0    9850.0
# 19     7.983200e+09   230000.0       3.0       1.00       1250.0    9774.0
# 20     6.300501e+09   385000.0       4.0       1.75       1620.0    4980.0
# 21     2.524049e+09  2000000.0       3.0       2.75       3050.0   44867.0
# 22     7.137970e+09   285000.0       5.0       2.50       2270.0    6300.0
# 23     8.091400e+09   252700.0       2.0       1.50       1070.0    9643.0
# 24     3.814700e+09   329000.0       3.0       2.25       2450.0    6500.0
# 25     1.202000e+09   233000.0       3.0       2.00       1710.0    4697.0
# 26     1.794500e+09   937000.0       3.0       1.75       2450.0    2691.0
# 27     3.303700e+09   667000.0       3.0       1.00       1400.0    1581.0
# 28     5.101402e+09   438000.0       3.0       1.75       1520.0    6380.0
# 29     1.873100e+09   719000.0       4.0       2.50       2570.0    7173.0
# ...             ...        ...       ...        ...          ...       ...
# 21577           NaN        NaN       NaN        NaN          NaN       NaN
# 21578           NaN        NaN       NaN        NaN          NaN       NaN
# 21579           NaN        NaN       NaN        NaN          NaN       NaN
# 21580           NaN        NaN       NaN        NaN          NaN       NaN
# 21581           NaN        NaN       NaN        NaN          NaN       NaN
# 21582           NaN        NaN       NaN        NaN          NaN       NaN
# 21583           NaN        NaN       NaN        NaN          NaN       NaN
# 21584           NaN        NaN       NaN        NaN          NaN       NaN
# 21585           NaN        NaN       NaN        NaN          NaN       NaN
# 21586           NaN        NaN       NaN        NaN          NaN       NaN
# 21587           NaN        NaN       NaN        NaN          NaN       NaN
# 21588           NaN        NaN       NaN        NaN          NaN       NaN
# 21589           NaN        NaN       NaN        NaN          NaN       NaN
# 21590           NaN        NaN       NaN        NaN          NaN       NaN
# 21591           NaN        NaN       NaN        NaN          NaN       NaN
# 21592           NaN        NaN       NaN        NaN          NaN       NaN
# 21593           NaN        NaN       NaN        NaN          NaN       NaN
# 21594           NaN        NaN       NaN        NaN          NaN       NaN
# 21595           NaN        NaN       NaN        NaN          NaN       NaN
# 21596           NaN        NaN       NaN        NaN          NaN       NaN
# 21597           NaN        NaN       NaN        NaN          NaN       NaN
# 21598           NaN        NaN       NaN        NaN          NaN       NaN
# 21599           NaN        NaN       NaN        NaN          NaN       NaN
# 21600           NaN        NaN       NaN        NaN          NaN       NaN
# 21601           NaN        NaN       NaN        NaN          NaN       NaN
# 21602           NaN        NaN       NaN        NaN          NaN       NaN
# 21603           NaN        NaN       NaN        NaN          NaN       NaN
# 21604           NaN        NaN       NaN        NaN          NaN       NaN
# 21605           NaN        NaN       NaN        NaN          NaN       NaN
# 21606           NaN        NaN       NaN        NaN          NaN       NaN
#
#        floors  condition  grade  zipcode
# 0         1.0        3.0    7.0  98178.0
# 1         2.0        3.0    7.0  98125.0
# 2         1.0        3.0    6.0  98028.0
# 3         1.0        5.0    7.0  98136.0
# 4         1.0        3.0    8.0  98074.0
# 5         1.0        3.0   11.0  98053.0
# 6         2.0        3.0    7.0  98003.0
# 7         1.0        3.0    7.0  98198.0
# 8         1.0        3.0    7.0  98146.0
# 9         2.0        3.0    7.0  98038.0
# 10        1.0        3.0    8.0  98007.0
# 11        1.0        4.0    7.0  98115.0
# 12        1.5        4.0    7.0  98028.0
# 13        1.0        4.0    7.0  98074.0
# 14        1.5        3.0    7.0  98107.0
# 15        2.0        3.0    9.0  98126.0
# 16        2.0        3.0    7.0  98019.0
# 17        1.5        4.0    7.0  98103.0
# 18        1.0        4.0    7.0  98002.0
# 19        1.0        4.0    7.0  98003.0
# 20        1.0        4.0    7.0  98133.0
# 21        1.0        3.0    9.0  98040.0
# 22        2.0        3.0    8.0  98092.0
# 23        1.0        3.0    7.0  98030.0
# 24        2.0        4.0    8.0  98030.0
# 25        1.5        5.0    6.0  98002.0
# 26        2.0        3.0    8.0  98119.0
# 27        1.5        5.0    8.0  98112.0
# 28        1.0        3.0    7.0  98115.0
# 29        2.0        3.0    8.0  98052.0
# ...       ...        ...    ...      ...
# 21577     NaN        NaN    NaN      NaN
# 21578     NaN        NaN    NaN      NaN
# 21579     NaN        NaN    NaN      NaN
# 21580     NaN        NaN    NaN      NaN
# 21581     NaN        NaN    NaN      NaN
# 21582     NaN        NaN    NaN      NaN
# 21583     NaN        NaN    NaN      NaN
# 21584     NaN        NaN    NaN      NaN
# 21585     NaN        NaN    NaN      NaN
# 21586     NaN        NaN    NaN      NaN
# 21587     NaN        NaN    NaN      NaN
# 21588     NaN        NaN    NaN      NaN
# 21589     NaN        NaN    NaN      NaN
# 21590     NaN        NaN    NaN      NaN
# 21591     NaN        NaN    NaN      NaN
# 21592     NaN        NaN    NaN      NaN
# 21593     NaN        NaN    NaN      NaN
# 21594     NaN        NaN    NaN      NaN
# 21595     NaN        NaN    NaN      NaN
# 21596     NaN        NaN    NaN      NaN
# 21597     NaN        NaN    NaN      NaN
# 21598     NaN        NaN    NaN      NaN
# 21599     NaN        NaN    NaN      NaN
# 21600     NaN        NaN    NaN      NaN
# 21601     NaN        NaN    NaN      NaN
# 21602     NaN        NaN    NaN      NaN
# 21603     NaN        NaN    NaN      NaN
# 21604     NaN        NaN    NaN      NaN
# 21605     NaN        NaN    NaN      NaN
# 21606     NaN        NaN    NaN      NaN
#
# [21607 rows x 10 columns]

# %%
df=df.dropna()

# %%
df=df.drop(columns=['id'])

# %%
df=df.drop(columns=['zipcode'])

# %%
y=df.iloc[:,0]
x=df.iloc[:,1:]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
le=LinearRegression()

# %%
le.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
ypred=le.predict(xtest)

# %%
ypred
# Out:
# array([390217.67579361, 567527.5512112 , 514117.13796534, 669095.0613254 ,
#        461042.26168384, 351852.58203093, 607592.98649287, 203799.15260286,
#        453906.97363089, 466988.71298627, 554121.47393442, 538274.22616619,
#        587785.50397063, 507558.39447139, 268248.88092119])

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(ytest,ypred)
